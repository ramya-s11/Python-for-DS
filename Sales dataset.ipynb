# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("SalesData.xlsx",parse_dates=True)
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television     56      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater     60       500.0
# 6  2018-04-18  Central   Martha     Steven    Television     75      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television     90      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television     32      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater     60       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television     90      1198.0
# ...

# %% [markdown]
# 1. Find the least amount sale that was done for each item.

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
min_sales = df.groupby('Item')['Sale_amt'].min()
min_sales
# Out:
# Item
# Cell Phone      3375.0
# Desk             250.0
# Home Theater    2000.0
# Television      8386.0
# Video Games      936.0
# Name: Sale_amt, dtype: float64

# %% [markdown]
# 2. Compute the total sales for each year and region across all items

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
df['year'] = df['OrderDate'].dt.year
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt  year
# 0  113810.0  2018
# 1   25000.0  2018
# 2   43128.0  2018
# 3    6075.0  2018
# 4   67088.0  2018

# %%
tot_sales_year = df.groupby('year')['Sale_amt'].sum()
tot_sales_year
# Out:
# year
# 2018    879029.0
# 2019    426646.5
# Name: Sale_amt, dtype: float64

# %%
tot_sales_region = df.groupby('Region')['Sale_amt'].sum()
tot_sales_region
# Out:
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %% [markdown]
# 3. Create new column 'days_diff' with number of days difference between reference date passed and each order date

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# Define reference date
reference_date = pd.to_datetime('2023-06-03')

# Calculate the time difference between reference date and order date
df['days_diff'] = (reference_date - df['OrderDate']).dt.days

# Print the resulting DataFrame
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television     56      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater     60       500.0
# 6  2018-04-18  Central   Martha     Steven    Television     75      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television     90      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television     32      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater     60       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television     90      1198.0
# ...

# %% [markdown]
# 4. Create a dataframe with two columns: 'manager', 'list_of_salesmen'. Column 'manager' will contain the unique managers present and column 'list_of_salesmen' will contain an array of all salesmen under each manager.

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
df_grouped = df.groupby('Manager')['SalesMan'].agg(list).reset_index()

# Rename 'salesman' column to 'list_of_salesmen'
df_grouped.rename(columns={'SalesMan': 'list_of_salesmen'}, inplace=True)

# Print the resulting DataFrame
df_grouped
# Out:
#    Manager                                   list_of_salesmen
# 0  Douglas  [Michael, Karen, John, Karen, John, Karen, Joh...
# 1  Hermann  [Shelli, Luis, Luis, Sigal, Sigal, Shelli, Lui...
# 2   Martha  [Alexander, Alexander, Steven, Alexander, Dian...
# 3  Timothy  [David, Stephen, David, Stephen, David, David,...

# %% [markdown]
# 5. For all regions find number of salesman and total sales. Return as a dataframe with three columns - Region, salesmen_count and total_sales

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
tot_salesamt = df.groupby('Region')['Sale_amt'].sum()
print(tot_salesamt)

dataframe = data.groupby('Region').agg({'SalesMan': 'count', 'Sale_amt': 'sum'}).reset_index()
dataframe.columns = ['Region', 'salesmen_count', 'total_sales']
dataframe
# Out:
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64
#     Region  salesmen_count  total_sales
# 0  Central              24     829769.5
# 1     East              13     321007.0
# 2     West               6     154899.0

# %% [markdown]
# 6. Create a dataframe with total sales as percentage for each manager. Dataframe to contain manager and percent_sales

# %%
df.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television     56      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
df1 = df.groupby('Manager')['Sale_amt'].sum().reset_index()
df1.columns = ['Manager', 'manager_sales']

total_sum = df1['manager_sales'].sum()
df1['percentage'] = (df1['manager_sales'] / total_sum) * 100
df1
# Out:
#    Manager  manager_sales  percentage
# 0  Douglas       239056.0   18.308990
# 1  Hermann       365108.5   27.963188
# 2   Martha       472493.0   36.187629
# 3  Timothy       229018.0   17.540193
